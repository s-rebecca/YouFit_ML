# %% [markdown]
# # YouFit : Your Fitness Assistant

# %% [markdown]
# Team :

# %% [markdown]
# Gowtham Govind - CB.EN.U4CSE21019

# %% [markdown]
# Sajith Rajan P - CB.EN.U4CSE21052

# %% [markdown]
# Samya Rebecca  - CB.EN.U4CSE21053

# %% [markdown]
# Saravanak Karthick - CB.EN.U4CSE21054

# %% [markdown]
# Veda Yasaswani Suseela - CB.EN.U4CSE21060

# %% [markdown]
# ## Files 5 models

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# All the dataset can be found in the dataset folder

# %% [markdown]
# # Individual contribution

# %% [markdown]
# Gowtham Govind - CB.EN.U4CSE21019 - Calories Prediction

# %% [markdown]
# Sajith Rajan P - CB.EN.U4CSE21052 - BMI Classification - Random Forest - Parkinson's Diseases -SVM

# %% [markdown]
# Samya Rebecca  - CB.EN.U4CSE21053 - MultipleLinearRegression  - CardioRespiratory Fitness - Naive_Bayes

# %% [markdown]
# Saravanak Karthick - CB.EN.U4CSE21054 - Linear - Workout Prediction - KNN

# %% [markdown]
# Veda Yasaswani Suseela - CB.EN.U4CSE21060 - Heart_disease Prediction

# %% [markdown]
# # All the Files are uploaded to github.com
# # The Zip folder contains the Team Files.
# # 6 dataset , 8 Jupyter Notebook
